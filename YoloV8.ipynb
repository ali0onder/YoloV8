# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# Found https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt locally at yolov8s.pt
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train5/results.png', width=1000)

# %%
Image(filename=f'/content/runs/detect/train5/confusion_matrix.png', width=1000)

# %%
Image(filename=f'/content/runs/detect/train5/val_batch2_pred.jpg', width=1000)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/halo-3/data.yaml
# Out:
# 2023-07-15 11:21:03.817217: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-15 11:21:04.661578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/halo-3/valid/labels.cache... 123 images, 39 backgrounds, 0 corrupt: 100% 123/123 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.56it/s]
#                    all        123        201       0.96      0.893      0.962      0.711
# ...
